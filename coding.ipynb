# %%
import geopandas as gpd
import pandas as pd

# %%
shp = gpd.read_file(r'Data/MetropAccess_YKR_grid/MetropAccess_YKR_grid_EurefFIN.shp')

# %%
transport = pd.read_csv('Data/travel_times_to_ 5859425.csv', delimiter=";")

# %%
shp.set_index('YKR_ID',inplace=True)
shp.drop(columns=['x','y'],inplace=True)

# %%
data = shp.join(transport.set_index("from_id"))

# %%
data = data.loc[(data['walk_t']>=0)|(data['walk_d']>=0)|(data['pt_r_tt']>=0)|(data['pt_r_t']>=0)|(data['pt_r_d']>=0)|(data['pt_m_tt']>=0)|(data['pt_m_t']>=0)|(data['pt_m_d']>=0)|(data['car_r_t']>=0)|(data['car_r_d']>=0)|(data['car_m_t']>=0)|(data['car_m_d']>=0)]

# %%
data
# Out:
#                                                   geometry    to_id  walk_t  \
# YKR_ID
# 5785640  POLYGON ((382000.000 6697750.000, 381750.000 6...  5859425     211
# 5785641  POLYGON ((382250.000 6697750.000, 382000.000 6...  5859425     198
# 5785642  POLYGON ((382500.000 6697750.000, 382250.000 6...  5859425     199
# 5785643  POLYGON ((382750.000 6697750.000, 382500.000 6...  5859425     203
# 5787544  POLYGON ((381250.000 6697500.000, 381000.000 6...  5859425     204
# ...                                                    ...      ...     ...
# 6016697  POLYGON ((372750.000 6665500.000, 372500.000 6...  5859425     440
# 6016698  POLYGON ((373000.000 6665500.000, 372750.000 6...  5859425     438
# 6016699  POLYGON ((373250.000 6665500.000, 373000.000 6...  5859425     440
# 6018253  POLYGON ((372750.000 6665250.000, 372500.000 6...  5859425     443
# 6018254  POLYGON ((373000.000 6665250.000, 372750.000 6...  5859425     441
#
#          walk_d  pt_r_tt  pt_r_t  pt_r_d  pt_m_tt  pt_m_t  pt_m_d  car_r_t  \
# YKR_ID
# 5785640   14779      147     118   19754      157     126   19172       42
# 5785641   13842      144     124   19960      157     129   19377       42
# 5785642   13922      144     126   20077      157     131   19495       46
# 5785643   14214      154     127   20370      160     135   19788       50
# 5787544   14290      131     114   19264      134     111   19264       41
# ...         ...      ...     ...     ...      ...     ...     ...      ...
# 6016697   30784      146     121   42935      160     132   43752       64
# 6016698   30639      146     119   42789      160     130   43606       65
# 6016699   30766      146     121   42916      160     132   43734       67
# 6018253   30996      146     124   43146      160     135   43964       66
# 6018254   30866      146     122   43016      160     133   43834       68
#
#          car_r_d  car_m_t  car_m_d
# YKR_ID
# 5785640    21175       37    21175
# 5785641    21386       37    21386
# 5785642    18053       42    18053
# 5785643    20610       46    20610
# 5787544    20749       36    20749
# ...          ...      ...      ...
# 6016697    40656       56    40634
# 6016698    40687       57    40665
# 6016699    40375       59    40352
# 6018253    40864       58    40842
# 6018254    40962       60    40940
#
# [13140 rows x 14 columns]

# %%
data.to_crs(epsg=4326).to_file('data.geojson',driver="GeoJSON")
